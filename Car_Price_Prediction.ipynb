# %% [markdown]
# ### **Import dataset and explore it**

# %%
import pandas as pd 
import numpy as np

# %%
df0 = pd.read_csv("Datasets/car_purchasing.csv", encoding="ISO-8859-1")
df = df0.copy()

# %%
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
df.tail()
# Out:
#     customer name                     customer e-mail      country  gender  \
# 495        Walter                 ligula@Cumsociis.ca        Nepal       0
# 496         Vanna  Cum.sociis.natoque@Sedmolestie.edu     Zimbabwe       1
# 497         Pearl       penatibus.et@massanonante.com  Philippines       1
# 498          Nell   Quisque.varius@arcuVivamussit.net     Botswana       1
# 499         Marla           Camaron.marla@hotmail.com       marlal       1
#
#            age  annual Salary  credit card debt    net worth  \
# 495  41.462515    71942.40291       6995.902524  541670.1016
# 496  37.642000    56039.49793      12301.456790  360419.0988
# 497  53.943497    68888.77805      10611.606860  764531.3203
# 498  59.160509    49811.99062      14013.034510  337826.6382
# 499  46.731152    61370.67766       9391.341628  462946.4924
#
#      car purchase amount
# 495          48901.44342
# 496          31491.41457
# 497          64147.28888
# 498          45442.15353
# ...

# %%
df.shape
# Out:
# (500, 9)

# %%
df.isna().sum()
# Out:
# customer name          0
# customer e-mail        0
# country                0
# gender                 0
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %%
df.describe().T
# Out:
#                      count           mean            std      min  \
# gender               500.0       0.506000       0.500465      0.0
# age                  500.0      46.241674       7.978862     20.0
# annual Salary        500.0   62127.239608   11703.378228  20000.0
# credit card debt     500.0    9607.645049    3489.187973    100.0
# net worth            500.0  431475.713625  173536.756340  20000.0
# car purchase amount  500.0   44209.799218   10773.178744   9000.0
#
#                                25%            50%            75%        max
# gender                    0.000000       1.000000       1.000000        1.0
# age                      40.949969      46.049901      51.612263       70.0
# annual Salary         54391.977195   62915.497035   70117.862005   100000.0
# credit card debt       7397.515792    9655.035568   11798.867487    20000.0
# net worth            299824.195900  426750.120650  557324.478725  1000000.0
# ...

# %%
df["car purchase amount"].sort_values()
# Out:
# 453     9000.00000
# 37     10092.22509
# 270    12536.93842
# 89     12895.71468
# 30     17584.56963
#           ...
# 45     68925.09447
# 470    69669.47402
# 400    70598.96768
# 289    70878.29664
# 315    80000.00000
# Name: car purchase amount, Length: 500, dtype: float64

# %%
df.loc[df["car purchase amount"] == 9000]
# Out:
#     customer name                   customer e-mail         country  gender  \
# 453       Tatyana  sem@parturientmontesnascetur.net  Norfolk Island       0
#
#            age  annual Salary  credit card debt    net worth  \
# 453  25.179893    45092.74073       11380.09288  158758.3577
#
#      car purchase amount
# 453               9000.0

# %% [markdown]
# #### **Analysis of Columns**

# %%
df['gender'].value_counts().plot(kind='bar');

# %%
df['age'].value_counts().plot(kind='line', marker='+', alpha=0.4, color='darkred', markersize=19, figsize=(10, 5));

# %%
df.columns
# Out:
# Index(['customer name', 'customer e-mail', 'country', 'gender', 'age',
#        'annual Salary', 'credit card debt', 'net worth',
#        'car purchase amount'],
#       dtype='object')

# %%
df['annual Salary'].value_counts().plot(kind='line', marker='+', alpha=0.4, color='darkblue', markersize=19, figsize=(10, 5));

# %%
df['credit card debt'].value_counts().plot(kind='line', marker='+', alpha=0.4, color='darkgreen', markersize=19, figsize=(10, 5));

# %%
df['car purchase amount'].value_counts().plot(kind='line', marker='+', alpha=0.4, color='darkorange', markersize=19, figsize=(10, 5));

# %% [markdown]
# ### **EDA**

# %% [markdown]
# #### **designing of columns**

# %%
df
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %%
df.columns = [col.replace(' ', '_') for col in df.columns]

# %%
df
# Out:
#        customer_name                                    customer_e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual_Salary  credit_card_debt  \
# ...

# %%
df = df.drop(['customer_name', 'customer_e-mail', 'country'], axis=1)

# %%
df
# Out:
#      gender        age  annual_Salary  credit_card_debt    net_worth  \
# 0         0  41.851720    62812.09301      11609.380910  238961.2505
# 1         0  40.870623    66646.89292       9572.957136  530973.9078
# 2         1  43.152897    53798.55112      11160.355060  638467.1773
# 3         1  58.271369    79370.03798      14426.164850  548599.0524
# 4         1  57.313749    59729.15130       5358.712177  560304.0671
# ..      ...        ...            ...               ...          ...
# 495       0  41.462515    71942.40291       6995.902524  541670.1016
# 496       1  37.642000    56039.49793      12301.456790  360419.0988
# 497       1  53.943497    68888.77805      10611.606860  764531.3203
# 498       1  59.160509    49811.99062      14013.034510  337826.6382
# 499       1  46.731152    61370.67766       9391.341628  462946.4924
#
#      car_purchase_amount
# 0            35321.45877
# 1            45115.52566
# 2            42925.70921
# 3            67422.36313
# ...

# %% [markdown]
# #### **apply standardization**

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
df.iloc[:, 1:] = scaler.fit_transform(df.iloc[:, 1:])

# %%
df
# Out:
#      gender       age  annual_Salary  credit_card_debt  net_worth  \
# 0         0  0.437034       0.535151          0.578361   0.223430
# 1         0  0.417412       0.583086          0.476028   0.521402
# 2         1  0.463058       0.422482          0.555797   0.631089
# 3         1  0.765427       0.742125          0.719908   0.539387
# 4         1  0.746275       0.496614          0.264257   0.551331
# ..      ...       ...            ...               ...        ...
# 495       0  0.429250       0.649280          0.346528   0.532316
# 496       1  0.352840       0.450494          0.613139   0.347366
# 497       1  0.678870       0.611110          0.528221   0.759726
# 498       1  0.783210       0.372650          0.699147   0.324313
# 499       1  0.534623       0.517133          0.466902   0.451986
#
#      car_purchase_amount
# 0               0.370725
# 1               0.508669
# 2               0.477827
# 3               0.822850
# 4               0.660781
# ...

# %% [markdown]
# #### **split dataframe**

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('car_purchase_amount', axis=1)
y = df['car_purchase_amount']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### **Create Model**

# %%
from sklearn.linear_model import LinearRegression as LR

model = LR()

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %% [markdown]
# ### **Evaluation**

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib

# %%
plt.figure(figsize=(20, 5))
plt.plot(y_test.values, color='black', label='Actual')
plt.scatter(range(len(y_pred)), y_pred, color='red', marker='+', label='Predicted');

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mean_absolute_error = mean_absolute_error(y_test, y_pred)
mean_squared_error = mean_squared_error(y_test, y_pred)
root_mean_squared_error = np.sqrt(mean_squared_error)   
r2_score = r2_score(y_test, y_pred)

# %%
my_data = {
    'Mean Absolute Error': mean_absolute_error,
    'Mean Squared Error': mean_squared_error,
    'Root Mean Squared Error': root_mean_squared_error,
    'R2 Score': r2_score
}

df_eval = pd.DataFrame(data=my_data, index=['Values'])

# %%
df_eval
# Out:
#         Mean Absolute Error  Mean Squared Error  Root Mean Squared Error  \
# Values             0.000016        4.046862e-10                  0.00002
#
#         R2 Score
# Values       1.0

# %%
X_test
# Out:
#      gender       age  annual_Salary  credit_card_debt  net_worth
# 361       0  0.322538       0.680251          0.511263   0.542188
# 73        1  0.555795       0.489240          0.227666   0.463108
# 374       1  0.742692       0.596905          0.691051   0.650182
# 155       0  0.604391       0.442269          0.250665   0.000000
# 104       0  0.569528       0.549688          0.528385   0.889224
# ..      ...       ...            ...               ...        ...
# 266       1  0.407241       0.424017          0.449557   0.505414
# 23        1  0.540446       0.400345          0.596023   0.682108
# 222       0  0.549019       0.513292          0.601320   0.499534
# 261       0  0.354456       0.366830          0.287830   0.469067
# 426       1  0.438623       0.443937          0.397473   0.381867
#
# [150 rows x 5 columns]

# %%
df0.head(2)
# Out:
#    customer name                                    customer e-mail   country  \
# 0  Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu  Bulgaria
# 1  Harlan Barnes                                eu.dolor@diam.co.uk    Belize
#
#    gender        age  annual Salary  credit card debt    net worth  \
# 0       0  41.851720    62812.09301      11609.380910  238961.2505
# 1       0  40.870623    66646.89292       9572.957136  530973.9078
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566

# %% [markdown]
# ### **Create Pipeline**

# %%
from sklearn.pipeline import Pipeline
import joblib
import sklearn

# %%
df = df0.copy()

# %%
df.columns = [col.replace(' ', '_') for col in df.columns]
df = df.drop(['customer_name', 'customer_e-mail', 'country'], axis=1)

# %%
X = df.drop('car_purchase_amount', axis=1)
y = df['car_purchase_amount']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
pipeline = Pipeline([
    ('scaler', MinMaxScaler()),
    ('model', LR())
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('model', LinearRegression())])

# %%
print("pandas==" + (pd.__version__))
print("numpy==" + (np.__version__))
print("sklearn==" + (sklearn.__version__))
print("matplotlib==" + (matplotlib.__version__))
print("joblib==" + str(joblib.__version__))
# Out:
# pandas==2.1.4
# numpy==1.26.4
# sklearn==1.4.1.post1
# matplotlib==3.8.2
# joblib==1.3.2

# %%
with open('Car_Price_Prediction.pkl', 'wb') as f:
    joblib.dump(pipeline, f)

print("Pipeline has been saved to Car_Price_Prediction.pkl")
# Out:
# Pipeline has been saved to Car_Price_Prediction.pkl

# %%
with open('Car_Price_Prediction.pkl', 'rb') as f:
    loaded_pipeline = joblib.load(f)

print("Pipeline has been loaded from Car_Price_Prediction.pkl")
# Out:
# Pipeline has been loaded from Car_Price_Prediction.pkl

# %%
y_pred = loaded_pipeline.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error of the loaded pipeline: {mse:.2f}")
# Out:
# Mean Squared Error of the loaded pipeline: 2.04

# %%
X
# Out:
#      gender        age  annual_Salary  credit_card_debt    net_worth
# 0         0  41.851720    62812.09301      11609.380910  238961.2505
# 1         0  40.870623    66646.89292       9572.957136  530973.9078
# 2         1  43.152897    53798.55112      11160.355060  638467.1773
# 3         1  58.271369    79370.03798      14426.164850  548599.0524
# 4         1  57.313749    59729.15130       5358.712177  560304.0671
# ..      ...        ...            ...               ...          ...
# 495       0  41.462515    71942.40291       6995.902524  541670.1016
# 496       1  37.642000    56039.49793      12301.456790  360419.0988
# 497       1  53.943497    68888.77805      10611.606860  764531.3203
# 498       1  59.160509    49811.99062      14013.034510  337826.6382
# 499       1  46.731152    61370.67766       9391.341628  462946.4924
#
# [500 rows x 5 columns]

# %%
new_data = {
    'gender': [1],
    'age': [20],
    'annual_Salary': [20000],
    'credit_card_debt': [100],
    'net_worth': [80000]
}

new_df = pd.DataFrame(data=new_data)

# %%
new_df
# Out:
#    gender  age  annual_Salary  credit_card_debt  net_worth
# 0       1   20          20000               100      80000

# %%
new_y_pred = loaded_pipeline.predict(new_df)

# %%
new_y_pred
# Out:
# array([-11750.64680376])
